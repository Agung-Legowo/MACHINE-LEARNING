# %%
import numpy as np
import matplotlib.pyplot as nt

jd = 10000
x=np.array([i*0.0001 + np.random.randn() for i in range(jd)])
y=np.array([i*0.0001 for i in range(jd)])

#Buat Fungsi Linier
def fungsi_firman(m,x) :
    y=m*x
    return y

#Prediksi Fungsi Garis
x_prediksi= np.array([0,1000])
m_prediksi=1
y_prediksi= fungsi_Agung(x_prediksi,m_prediksi)

nt.scatter(x,y, color="pink")
nt.plot(x_prediksi,y_prediksi,"red")
nt.axis([0,1,0,1])
nt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
